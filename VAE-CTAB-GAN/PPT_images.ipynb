# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

orig = pd.read_csv("C:/Users/GCU/Lending_club/Data_Analysis_lending-club/VAE-CTAB-GAN/Real_Datasets/train_category_1.csv")

col = "dti"

plt.figure(figsize=(10, 3))
sns.histplot(orig[col], color='blue', label='Original', kde=True, stat='count', alpha=0.4)

plt.title(f"Distribution of {col}")
plt.xlabel(col)
plt.ylabel("Count")
plt.legend()
plt.tight_layout()
#plt.savefig("figure_dti_distribution.png", dpi=300, bbox_inches='tight')
plt.show()
