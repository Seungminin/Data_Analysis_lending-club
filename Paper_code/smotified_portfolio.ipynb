# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.preprocessing import StandardScaler
from imblearn.under_sampling import RandomUnderSampler
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

from sklearn.metrics import roc_curve, auc, log_loss
from sklearn.metrics import classification_report, precision_recall_curve, auc
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
from tqdm import tqdm

import torch 
import os
import torch

import warnings
warnings.filterwarnings("ignore")

# %%
is_cuda = torch.cuda.is_available()
device = torch.device('cuda' if is_cuda else 'cpu')
print(device)
# Out:
# cuda

# %%
## Load original data
data_path = "C:/Users/GCU/Lending_club/Data_Analysis_lending-club/Dataset/return_feature_train.csv"
data = pd.read_csv(data_path, low_memory=False)

##load test data
test_data_path = "C:/Users/GCU/Lending_club/Data_Analysis_lending-club/Dataset/return_feature_test.csv"
test_data = pd.read_csv(test_data_path)

# %%
keep_features = ['grade', 'term_months', 'total_pymnt', 'total_pymnt_inv','total_il_high_credit_limit', 'loan_amnt']

data_classification = data.copy()
test_classification = test_data.copy()

data_classification = data_classification.drop(columns = keep_features)
test_classification = test_classification.drop(columns = keep_features)

# %%
from imblearn.over_sampling import SMOTE
drop2 = ['loan_status', 'return']

def select_fully_paid(y_pred, method):
    scaler = StandardScaler()
    reg = LinearRegression()

    fully_paid_indices = (y_pred == 0)
    test_regression = test_data[fully_paid_indices]
    test_regression['return'] = (test_regression['total_pymnt_inv'] - test_regression['loan_amnt'])/test_regression['loan_amnt']

    train_regression = data.copy()

    if method == 'Base':
        train_regression['return'] = (train_regression['total_pymnt_inv'] - train_regression['loan_amnt'])/train_regression['loan_amnt']

        drop_features = ['loan_status', 'total_pymnt_inv', 'total_pymnt', 'grade', 'term_months','total_il_high_credit_limit', 'loan_amnt']
        train_regression = train_regression.drop(columns=drop_features)
        test_regression = test_regression.drop(columns=drop_features)

        data_x = train_regression.drop(columns='return')
        data_y = train_regression[['return']]

        test_x = test_regression.drop(columns = 'return')
        test_y = test_regression[['return']]

        data_x_scaled = scaler.fit_transform(data_x)

        X_train = data_x_scaled
        y_train = data_y

        test_x_scaled = scaler.transform(test_x)

        reg.fit(X_train, y_train)

        #print(reg.coef_)
        y_pred = reg.predict(test_x_scaled)

        print("RMSE:", mean_squared_error(test_y, y_pred, squared=False))
        print("R²:", r2_score(test_y, y_pred))

        test_regression['predicted_return'] = reg.predict(test_x_scaled)

        top_10_percent = test_regression.sort_values(by='predicted_return', ascending=False).head(int(len(test_regression)*0.1))
        return method, top_10_percent
    
    elif method == 'Undersampling':
        train_regression['return'] = (train_regression['total_pymnt_inv'] - train_regression['loan_amnt'])/train_regression['loan_amnt']
        drop_features = ['total_pymnt_inv', 'total_pymnt', 'grade', 'term_months','total_il_high_credit_limit', 'loan_amnt']
        train_regression = train_regression.drop(columns=drop_features)
        test_regression = test_regression.drop(columns=drop_features)

        X_train = train_regression.drop(columns='loan_status')
        y_train = train_regression[['loan_status']]

        undersampler = RandomUnderSampler(random_state=42)
        X_under, y_under = undersampler.fit_resample(X_train, y_train)

        data_under = pd.concat([pd.DataFrame(X_under, columns=X_train.columns), pd.DataFrame(y_under, columns=['loan_status'])], axis=1)

        data_x = data_under.drop(columns=drop2)  
        data_y = data_under[['return']]  

        test_x = test_regression.drop(columns = drop2)
        test_y = test_regression[['return']]

        data_x_scaled = scaler.fit_transform(data_x)

        X_train = data_x_scaled
        y_train = data_y

        test_x_scaled = scaler.transform(test_x)

        reg.fit(X_train, y_train)

        #print(reg.coef_)
        y_pred = reg.predict(test_x_scaled)

        print("RMSE:", mean_squared_error(test_y, y_pred, squared=False))
        print("R²:", r2_score(test_y, y_pred))

        test_regression['predicted_return'] = reg.predict(test_x_scaled)

        top_10_percent = test_regression.sort_values(by='predicted_return', ascending=False).head(int(len(test_regression)*0.1))

        return method, top_10_percent
    
    elif method == 'SMOTE':
        train_regression['return'] = (train_regression['total_pymnt_inv'] - train_regression['loan_amnt'])/train_regression['loan_amnt']
        drop_features = ['total_pymnt_inv', 'total_pymnt', 'grade', 'term_months','total_il_high_credit_limit', 'loan_amnt']
        train_regression = train_regression.drop(columns=drop_features)
        test_regression = test_regression.drop(columns=drop_features)

        X_train = train_regression.drop(columns='loan_status')
        y_train = train_regression[['loan_status']]

        smote = SMOTE(random_state=42)

        X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

        augmentation_data = pd.concat([X_train_smote, y_train_smote], axis = 1)
        data_x = augmentation_data.drop(columns=drop2)
        data_y = augmentation_data[['return']]

        test_x = test_regression.drop(columns = drop2)
        test_y = test_regression[['return']]

        data_x_scaled = scaler.fit_transform(data_x)

        X_train = data_x_scaled
        y_train = data_y

        test_x_scaled = scaler.transform(test_x)

        reg.fit(X_train, y_train)

        #print(reg.coef_)
        y_pred = reg.predict(test_x_scaled)

        print("RMSE:", mean_squared_error(test_y, y_pred, squared=False))
        print("R²:", r2_score(test_y, y_pred))

        test_regression['predicted_return'] = reg.predict(test_x_scaled)
        top_10_percent = test_regression.sort_values(by='predicted_return', ascending=False).head(int(len(test_regression)*0.1))

        return method, top_10_percent
    
    elif method == 'table-gan':
        train_regression['return'] = (train_regression['total_pymnt_inv'] - train_regression['loan_amnt'])/train_regression['loan_amnt']
        drop_features = ['loan_status', 'total_pymnt_inv', 'total_pymnt', 'grade', 'term_months','total_il_high_credit_limit', 'loan_amnt']
        train_regression = train_regression.drop(columns=drop_features)
        test_regression = test_regression.drop(columns=drop_features)
        
        fake_path = "C:/Users/GCU/Lending_club/Data_Analysis_lending-club/tablegan/samples/return_feature/return_feature_OI_11_00_fake.csv"
        fake = pd.read_csv(fake_path)
        fake['loan_status'] = 1

        fake_regression = fake.copy()

        fake_regression['return'] = (fake_regression['total_pymnt_inv'] - fake_regression['loan_amnt'])/fake_regression['loan_amnt']
        fake_regression = fake_regression.drop(columns=drop_features)

        train_total = pd.concat([train_regression, fake_regression])

        data_x = train_total.drop(columns='return')
        data_y = train_total[['return']]

        test_x = test_regression.drop(columns = 'return')
        test_y = test_regression[['return']]

        data_x_scaled = scaler.fit_transform(data_x)

        X_train = data_x_scaled
        y_train = data_y

        test_x_scaled = scaler.transform(test_x)

        reg.fit(X_train, y_train)

        #print(reg.coef_)
        y_pred = reg.predict(test_x_scaled)

        print("RMSE:", mean_squared_error(test_y, y_pred, squared=False))
        print("R²:", r2_score(test_y, y_pred))

        test_regression['predicted_return'] = reg.predict(test_x_scaled)
        top_10_percent = test_regression.sort_values(by='predicted_return', ascending=False).head(int(len(test_regression)*0.1))

        return method, top_10_percent
        
    elif method == 'Smotified-gan':
        train_regression['return'] = (train_regression['total_pymnt_inv'] - train_regression['loan_amnt'])/train_regression['loan_amnt']
        drop_features = ['loan_status', 'total_pymnt_inv', 'total_pymnt', 'grade', 'term_months','total_il_high_credit_limit', 'loan_amnt']
        train_regression = train_regression.drop(columns=drop_features)
        test_regression = test_regression.drop(columns=drop_features)
        
        fake_path = "C:/Users/GCU/Lending_club/Data_Analysis_lending-club/tablegan/samples/oversampled/oversampled_OI_11_00_fake.csv"
        fake = pd.read_csv(fake_path)
        fake['loan_status'] = 1
        
        fake_regression = fake.copy()

        fake_regression['return'] = (fake_regression['total_pymnt_inv'] - fake_regression['loan_amnt'])/fake_regression['loan_amnt']
        fake_regression = fake_regression.drop(columns=drop_features)

        train_total = pd.concat([train_regression, fake_regression])

        data_x = train_total.drop(columns='return')
        data_y = train_total[['return']]

        test_x = test_regression.drop(columns = 'return')
        test_y = test_regression[['return']]

        data_x_scaled = scaler.fit_transform(data_x)

        X_train = data_x_scaled
        y_train = data_y

        test_x_scaled = scaler.transform(test_x)

        reg.fit(X_train, y_train)

        #print(reg.coef_)
        y_pred = reg.predict(test_x_scaled)

        print("RMSE:", mean_squared_error(test_y, y_pred, squared=False))
        print("R²:", r2_score(test_y, y_pred))

        test_regression['predicted_return'] = reg.predict(test_x_scaled)
        top_10_percent = test_regression.sort_values(by='predicted_return', ascending=False).head(int(len(test_regression)*0.1))

        return method, top_10_percent

# %%
summary_with_sharpe = []

def linear_portfolio(Method, top_10_indices):
    selected = test_data.loc[top_10_indices.index].copy()
    returns = (selected['total_pymnt_inv'] - selected['loan_amnt']) / selected['loan_amnt']
    
    avg_return = returns.mean()
    std_return = returns.std()
    sharpe_ratio = avg_return / std_return if std_return != 0 else np.nan

    summary_with_sharpe.append({
        'Method': Method,
        'Average Return': avg_return * 100,
        'Std Dev': std_return,
        'Sharpe Ratio': sharpe_ratio
    })

# %%
from imblearn.over_sampling import SMOTE
from sklearn.utils import shuffle

def return_evaluation(model, data_x, data_y, X_test, y_test, method):
    print(f"Preprocessing method : {method}")

    if method == 'Base':
        X_train, X_val, y_train, y_val = train_test_split(data_x, data_y, test_size=0.2,
                                                           random_state=42, stratify=data_y)
        model.fit(
        X_train, y_train,
        eval_set=[(X_train, y_train), (X_val, y_val)],  # Train & Validation Loss 저장
        verbose=True
        )

        y_prob = model.predict_proba(X_test)[:, 1]  # ROC Curve & PRC에 필요

        threshold = 0.5
        y_pred = (y_prob >= threshold).astype(int)


    elif method == 'Undersampling':
        X_train, X_val, y_train, y_val = train_test_split(data_x, data_y, test_size=0.13, random_state=42, stratify=data_y)
        undersampler = RandomUnderSampler(random_state=42)
        X_under, y_under = undersampler.fit_resample(X_train, y_train)

        data_under = pd.concat([pd.DataFrame(X_under, columns=data_x.columns), pd.DataFrame(y_under, columns=['loan_status'])], axis=1)
        X_train = data_under.drop(columns=['loan_status'])  # Feature (입력 데이터)
        y_train = data_under[['loan_status']]  # Target (타겟 변수)

        model.fit(
        X_train, y_train,
        eval_set=[(X_train, y_train), (X_val, y_val)],  # Train & Validation Loss 저장
        verbose=True
        )
        y_prob = model.predict_proba(X_test)[:, 1]  # ROC Curve & PRC에 필요

        threshold = 0.5
        y_pred = (y_prob >= threshold).astype(int)

    elif method == 'SMOTE':
        X_train, X_val, y_train, y_val = train_test_split(data_x, data_y, test_size=0.33, random_state=42, stratify=data_y)

        smote = SMOTE(random_state=42)

        X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

        augmentation_data = pd.concat([X_train_smote, y_train_smote], axis = 1)
        X_train = augmentation_data.drop(columns='loan_status')
        y_train = augmentation_data[['loan_status']]

        model.fit(
            X_train, y_train,
            eval_set=[(X_train, y_train), (X_val, y_val)],  # Train & Validation Loss 저장
            verbose=True
        )
        y_prob = model.predict_proba(X_test)[:, 1]  # ROC Curve & PRC에 필요

        threshold = 0.5
        y_pred = (y_prob >= threshold).astype(int)
    
    elif method == 'table-gan':
        fake_path = "C:/Users/GCU/Lending_club/Data_Analysis_lending-club/tablegan/samples/return_feature/return_feature_OI_11_00_fake.csv"
        fake = pd.read_csv(fake_path)
        fake['loan_status'] = 1
        
        keep_features = ['grade', 'term_months', 'total_pymnt', 'total_pymnt_inv','total_il_high_credit_limit', 'loan_amnt']
        fake_Classification = fake.copy()
        fake_Classification = fake_Classification.drop(columns = keep_features)

        X_train, X_val, y_train, y_val = train_test_split(data_x, data_y, test_size=0.33, random_state=42, stratify=data_y)
        train_dataset = pd.concat([X_train, y_train], axis=1)
        
        train_total = pd.concat([train_dataset,fake_Classification])
        train_total = shuffle(train_total, random_state=42)

        X_train = train_total.drop(columns='loan_status')
        y_train = train_total[['loan_status']]

        model.fit(
            X_train, y_train,
            eval_set=[(X_train, y_train), (X_val, y_val)],  # Train & Validation Loss 저장
            verbose=True
        )
        y_prob = model.predict_proba(X_test)[:, 1]  # ROC Curve & PRC에 필요

        threshold = 0.5
        y_pred = (y_prob >= threshold).astype(int)
        
    elif method == 'Smotified-gan':
        #Fake dataset
        fake_path = "C:/Users/GCU/Lending_club/Data_Analysis_lending-club/tablegan/samples/oversampled/oversampled_OI_11_00_fake.csv"
        fake = pd.read_csv(fake_path)
        fake['loan_status'] = 1

        keep_features = ['grade', 'term_months', 'total_pymnt', 'total_pymnt_inv','total_il_high_credit_limit', 'loan_amnt']
        fake_Classification = fake.copy()
        fake_Classification = fake_Classification.drop(columns = keep_features)
        
        X_train, X_val, y_train, y_val = train_test_split(data_x, data_y, test_size=0.2, stratify=data_y)
        train_dataset = pd.concat([X_train, y_train], axis=1)
        
        train_total = pd.concat([train_dataset,fake_Classification])
        train_total = shuffle(train_total)

        X_train = train_total.drop(columns='loan_status')
        y_train = train_total[['loan_status']]

        model.fit(
            X_train, y_train,
            eval_set=[(X_train, y_train), (X_val, y_val)],  # Train & Validation Loss 저장
            verbose=True
        )
        y_prob = model.predict_proba(X_test)[:, 1]  # ROC Curve & PRC에 필요

        threshold = 0.5
        y_pred = (y_prob >= threshold).astype(int)
    
    #10% index뽑기기
    Method, top_10_indices = select_fully_paid(y_pred, method)

    #portfolio 만들기들기
    linear_portfolio(Method, top_10_indices)

# %%
Methods = ['Base', 'Undersampling', 'SMOTE', 'table-gan','Smotified-gan']

X_test = test_classification.drop(columns='loan_status')
y_test = test_classification['loan_status']

returns_df = pd.DataFrame()

for method in Methods:
    data_x = data_classification.drop(columns='loan_status')
    data_y = data_classification['loan_status']

    model = XGBClassifier(
        n_estimators=500,
        learning_rate=0.01,
        objective='binary:logistic',
        eval_metric="logloss",
        random_state=42,
        verbosity=0
    )

    return_evaluation(model, data_x, data_y, X_test, y_test, method)

returns_with_sharpe_df = pd.DataFrame(summary_with_sharpe)

print(returns_with_sharpe_df.to_string(index=False))
# Out:
# Preprocessing method : Base
# [0]	validation_0-logloss:0.49199	validation_1-logloss:0.49201
# [1]	validation_0-logloss:0.48743	validation_1-logloss:0.48747
# [2]	validation_0-logloss:0.48300	validation_1-logloss:0.48305
# [3]	validation_0-logloss:0.47868	validation_1-logloss:0.47875
# [4]	validation_0-logloss:0.47446	validation_1-logloss:0.47455
# [5]	validation_0-logloss:0.47036	validation_1-logloss:0.47047
# [6]	validation_0-logloss:0.46636	validation_1-logloss:0.46648
# [7]	validation_0-logloss:0.46246	validation_1-logloss:0.46260
# [8]	validation_0-logloss:0.45865	validation_1-logloss:0.45880
# [9]	validation_0-logloss:0.45493	validation_1-logloss:0.45510
# [10]	validation_0-logloss:0.45130	validation_1-logloss:0.45148
# [11]	validation_0-logloss:0.44775	validation_1-logloss:0.44795
# [12]	validation_0-logloss:0.44428	validation_1-logloss:0.44450
# [13]	validation_0-logloss:0.44088	validation_1-logloss:0.44111
# [14]	validation_0-logloss:0.43757	validation_1-logloss:0.43781
# [15]	validation_0-logloss:0.43432	validation_1-logloss:0.43458
# [16]	validation_0-logloss:0.43114	validation_1-logloss:0.43141
# [17]	validation_0-logloss:0.42803	validation_1-logloss:0.42832
# [18]	validation_0-logloss:0.42498	validation_1-logloss:0.42528
# [19]	validation_0-logloss:0.42200	validation_1-logloss:0.42232
# [20]	validation_0-logloss:0.41908	validation_1-logloss:0.41941
# [21]	validation_0-logloss:0.41622	validation_1-logloss:0.41656
# [22]	validation_0-logloss:0.41341	validation_1-logloss:0.41376
# [23]	validation_0-logloss:0.41066	validation_1-logloss:0.41103
# [24]	validation_0-logloss:0.40796	validation_1-logloss:0.40834
# [25]	validation_0-logloss:0.40532	validation_1-logloss:0.40571
# [26]	validation_0-logloss:0.40272	validation_1-logloss:0.40313
# [27]	validation_0-logloss:0.40018	validation_1-logloss:0.40061
# [28]	validation_0-logloss:0.39769	validation_1-logloss:0.39812
# [29]	validation_0-logloss:0.39524	validation_1-logloss:0.39569
# [30]	validation_0-logloss:0.39284	validation_1-logloss:0.39330
# [31]	validation_0-logloss:0.39048	validation_1-logloss:0.39095
# [32]	validation_0-logloss:0.38817	validation_1-logloss:0.38865
# [33]	validation_0-logloss:0.38590	validation_1-logloss:0.38639
# [34]	validation_0-logloss:0.38366	validation_1-logloss:0.38417
# [35]	validation_0-logloss:0.38147	validation_1-logloss:0.38199
# [36]	validation_0-logloss:0.37932	validation_1-logloss:0.37985
# [37]	validation_0-logloss:0.37720	validation_1-logloss:0.37775
# [38]	validation_0-logloss:0.37512	validation_1-logloss:0.37568
# [39]	validation_0-logloss:0.37308	validation_1-logloss:0.37365
# [40]	validation_0-logloss:0.37107	validation_1-logloss:0.37166
# [41]	validation_0-logloss:0.36910	validation_1-logloss:0.36970
# [42]	validation_0-logloss:0.36716	validation_1-logloss:0.36777
# [43]	validation_0-logloss:0.36526	validation_1-logloss:0.36588
# [44]	validation_0-logloss:0.36339	validation_1-logloss:0.36402
# [45]	validation_0-logloss:0.36155	validation_1-logloss:0.36219
# [46]	validation_0-logloss:0.35974	validation_1-logloss:0.36039
# [47]	validation_0-logloss:0.35796	validation_1-logloss:0.35862
# [48]	validation_0-logloss:0.35621	validation_1-logloss:0.35689
# [49]	validation_0-logloss:0.35448	validation_1-logloss:0.35518
# [50]	validation_0-logloss:0.35279	validation_1-logloss:0.35349
# [51]	validation_0-logloss:0.35112	validation_1-logloss:0.35184
# [52]	validation_0-logloss:0.34949	validation_1-logloss:0.35021
# [53]	validation_0-logloss:0.34787	validation_1-logloss:0.34862
# [54]	validation_0-logloss:0.34629	validation_1-logloss:0.34704
# [55]	validation_0-logloss:0.34473	validation_1-logloss:0.34549
# [56]	validation_0-logloss:0.34319	validation_1-logloss:0.34397
# [57]	validation_0-logloss:0.34168	validation_1-logloss:0.34247
# [58]	validation_0-logloss:0.34020	validation_1-logloss:0.34099
# [59]	validation_0-logloss:0.33873	validation_1-logloss:0.33954
# [60]	validation_0-logloss:0.33729	validation_1-logloss:0.33811
# [61]	validation_0-logloss:0.33587	validation_1-logloss:0.33671
# [62]	validation_0-logloss:0.33448	validation_1-logloss:0.33532
# [63]	validation_0-logloss:0.33310	validation_1-logloss:0.33395
# [64]	validation_0-logloss:0.33175	validation_1-logloss:0.33261
# [65]	validation_0-logloss:0.33042	validation_1-logloss:0.33129
# [66]	validation_0-logloss:0.32911	validation_1-logloss:0.32999
# [67]	validation_0-logloss:0.32782	validation_1-logloss:0.32871
# [68]	validation_0-logloss:0.32655	validation_1-logloss:0.32745
# [69]	validation_0-logloss:0.32530	validation_1-logloss:0.32621
# [70]	validation_0-logloss:0.32407	validation_1-logloss:0.32499
# [71]	validation_0-logloss:0.32285	validation_1-logloss:0.32378
# [72]	validation_0-logloss:0.32166	validation_1-logloss:0.32260
# [73]	validation_0-logloss:0.32048	validation_1-logloss:0.32144
# [74]	validation_0-logloss:0.31932	validation_1-logloss:0.32029
# [75]	validation_0-logloss:0.31818	validation_1-logloss:0.31916
# [76]	validation_0-logloss:0.31706	validation_1-logloss:0.31804
# [77]	validation_0-logloss:0.31595	validation_1-logloss:0.31695
# [78]	validation_0-logloss:0.31486	validation_1-logloss:0.31587
# [79]	validation_0-logloss:0.31379	validation_1-logloss:0.31480
# [80]	validation_0-logloss:0.31273	validation_1-logloss:0.31376
# [81]	validation_0-logloss:0.31168	validation_1-logloss:0.31272
# [82]	validation_0-logloss:0.31066	validation_1-logloss:0.31171
# [83]	validation_0-logloss:0.30964	validation_1-logloss:0.31071
# [84]	validation_0-logloss:0.30864	validation_1-logloss:0.30971
# [85]	validation_0-logloss:0.30766	validation_1-logloss:0.30874
# [86]	validation_0-logloss:0.30669	validation_1-logloss:0.30778
# [87]	validation_0-logloss:0.30573	validation_1-logloss:0.30683
# [88]	validation_0-logloss:0.30479	validation_1-logloss:0.30590
# [89]	validation_0-logloss:0.30386	validation_1-logloss:0.30499
# [90]	validation_0-logloss:0.30295	validation_1-logloss:0.30408
# [91]	validation_0-logloss:0.30205	validation_1-logloss:0.30319
# [92]	validation_0-logloss:0.30116	validation_1-logloss:0.30232
# [93]	validation_0-logloss:0.30029	validation_1-logloss:0.30145
# [94]	validation_0-logloss:0.29943	validation_1-logloss:0.30060
# [95]	validation_0-logloss:0.29858	validation_1-logloss:0.29976
# [96]	validation_0-logloss:0.29774	validation_1-logloss:0.29893
# [97]	validation_0-logloss:0.29691	validation_1-logloss:0.29811
# [98]	validation_0-logloss:0.29610	validation_1-logloss:0.29731
# [99]	validation_0-logloss:0.29530	validation_1-logloss:0.29651
# [100]	validation_0-logloss:0.29450	validation_1-logloss:0.29573
# [101]	validation_0-logloss:0.29372	validation_1-logloss:0.29496
# [102]	validation_0-logloss:0.29295	validation_1-logloss:0.29420
# [103]	validation_0-logloss:0.29220	validation_1-logloss:0.29345
# [104]	validation_0-logloss:0.29145	validation_1-logloss:0.29271
# [105]	validation_0-logloss:0.29071	validation_1-logloss:0.29199
# [106]	validation_0-logloss:0.28999	validation_1-logloss:0.29127
# [107]	validation_0-logloss:0.28927	validation_1-logloss:0.29057
# [108]	validation_0-logloss:0.28857	validation_1-logloss:0.28987
# [109]	validation_0-logloss:0.28787	validation_1-logloss:0.28918
# [110]	validation_0-logloss:0.28718	validation_1-logloss:0.28850
# [111]	validation_0-logloss:0.28650	validation_1-logloss:0.28783
# [112]	validation_0-logloss:0.28584	validation_1-logloss:0.28718
# [113]	validation_0-logloss:0.28518	validation_1-logloss:0.28653
# [114]	validation_0-logloss:0.28453	validation_1-logloss:0.28589
# [115]	validation_0-logloss:0.28389	validation_1-logloss:0.28526
# [116]	validation_0-logloss:0.28326	validation_1-logloss:0.28464
# [117]	validation_0-logloss:0.28263	validation_1-logloss:0.28402
# [118]	validation_0-logloss:0.28202	validation_1-logloss:0.28342
# [119]	validation_0-logloss:0.28142	validation_1-logloss:0.28283
# [120]	validation_0-logloss:0.28082	validation_1-logloss:0.28224
# [121]	validation_0-logloss:0.28023	validation_1-logloss:0.28166
# [122]	validation_0-logloss:0.27966	validation_1-logloss:0.28109
# [123]	validation_0-logloss:0.27908	validation_1-logloss:0.28053
# [124]	validation_0-logloss:0.27852	validation_1-logloss:0.27997
# [125]	validation_0-logloss:0.27796	validation_1-logloss:0.27942
# [126]	validation_0-logloss:0.27741	validation_1-logloss:0.27888
# [127]	validation_0-logloss:0.27686	validation_1-logloss:0.27834
# [128]	validation_0-logloss:0.27633	validation_1-logloss:0.27782
# [129]	validation_0-logloss:0.27580	validation_1-logloss:0.27730
# [130]	validation_0-logloss:0.27528	validation_1-logloss:0.27679
# [131]	validation_0-logloss:0.27477	validation_1-logloss:0.27628
# [132]	validation_0-logloss:0.27426	validation_1-logloss:0.27579
# [133]	validation_0-logloss:0.27376	validation_1-logloss:0.27530
# [134]	validation_0-logloss:0.27327	validation_1-logloss:0.27481
# [135]	validation_0-logloss:0.27278	validation_1-logloss:0.27433
# [136]	validation_0-logloss:0.27230	validation_1-logloss:0.27386
# [137]	validation_0-logloss:0.27183	validation_1-logloss:0.27340
# [138]	validation_0-logloss:0.27136	validation_1-logloss:0.27294
# [139]	validation_0-logloss:0.27090	validation_1-logloss:0.27249
# [140]	validation_0-logloss:0.27045	validation_1-logloss:0.27204
# [141]	validation_0-logloss:0.27000	validation_1-logloss:0.27160
# [142]	validation_0-logloss:0.26955	validation_1-logloss:0.27117
# [143]	validation_0-logloss:0.26912	validation_1-logloss:0.27073
# [144]	validation_0-logloss:0.26868	validation_1-logloss:0.27031
# [145]	validation_0-logloss:0.26826	validation_1-logloss:0.26989
# [146]	validation_0-logloss:0.26784	validation_1-logloss:0.26948
# [147]	validation_0-logloss:0.26743	validation_1-logloss:0.26908
# [148]	validation_0-logloss:0.26702	validation_1-logloss:0.26867
# [149]	validation_0-logloss:0.26661	validation_1-logloss:0.26828
# [150]	validation_0-logloss:0.26622	validation_1-logloss:0.26789
# [151]	validation_0-logloss:0.26582	validation_1-logloss:0.26750
# [152]	validation_0-logloss:0.26543	validation_1-logloss:0.26712
# [153]	validation_0-logloss:0.26505	validation_1-logloss:0.26675
# [154]	validation_0-logloss:0.26467	validation_1-logloss:0.26638
# [155]	validation_0-logloss:0.26430	validation_1-logloss:0.26601
# [156]	validation_0-logloss:0.26394	validation_1-logloss:0.26565
# [157]	validation_0-logloss:0.26357	validation_1-logloss:0.26530
# [158]	validation_0-logloss:0.26322	validation_1-logloss:0.26495
# [159]	validation_0-logloss:0.26286	validation_1-logloss:0.26460
# [160]	validation_0-logloss:0.26251	validation_1-logloss:0.26426
# [161]	validation_0-logloss:0.26217	validation_1-logloss:0.26392
# [162]	validation_0-logloss:0.26183	validation_1-logloss:0.26359
# [163]	validation_0-logloss:0.26149	validation_1-logloss:0.26326
# [164]	validation_0-logloss:0.26116	validation_1-logloss:0.26293
# [165]	validation_0-logloss:0.26084	validation_1-logloss:0.26261
# [166]	validation_0-logloss:0.26051	validation_1-logloss:0.26230
# [167]	validation_0-logloss:0.26020	validation_1-logloss:0.26199
# [168]	validation_0-logloss:0.25988	validation_1-logloss:0.26168
# [169]	validation_0-logloss:0.25957	validation_1-logloss:0.26138
# [170]	validation_0-logloss:0.25926	validation_1-logloss:0.26107
# [171]	validation_0-logloss:0.25896	validation_1-logloss:0.26078
# [172]	validation_0-logloss:0.25867	validation_1-logloss:0.26049
# [173]	validation_0-logloss:0.25837	validation_1-logloss:0.26020
# [174]	validation_0-logloss:0.25808	validation_1-logloss:0.25992
# [175]	validation_0-logloss:0.25780	validation_1-logloss:0.25964
# [176]	validation_0-logloss:0.25751	validation_1-logloss:0.25936
# [177]	validation_0-logloss:0.25723	validation_1-logloss:0.25909
# [178]	validation_0-logloss:0.25696	validation_1-logloss:0.25882
# [179]	validation_0-logloss:0.25668	validation_1-logloss:0.25855
# [180]	validation_0-logloss:0.25642	validation_1-logloss:0.25829
# [181]	validation_0-logloss:0.25615	validation_1-logloss:0.25803
# [182]	validation_0-logloss:0.25588	validation_1-logloss:0.25777
# [183]	validation_0-logloss:0.25563	validation_1-logloss:0.25752
# [184]	validation_0-logloss:0.25537	validation_1-logloss:0.25727
# [185]	validation_0-logloss:0.25512	validation_1-logloss:0.25702
# [186]	validation_0-logloss:0.25487	validation_1-logloss:0.25678
# [187]	validation_0-logloss:0.25463	validation_1-logloss:0.25654
# [188]	validation_0-logloss:0.25438	validation_1-logloss:0.25631
# [189]	validation_0-logloss:0.25415	validation_1-logloss:0.25608
# [190]	validation_0-logloss:0.25391	validation_1-logloss:0.25585
# [191]	validation_0-logloss:0.25367	validation_1-logloss:0.25562
# [192]	validation_0-logloss:0.25344	validation_1-logloss:0.25539
# [193]	validation_0-logloss:0.25321	validation_1-logloss:0.25517
# [194]	validation_0-logloss:0.25299	validation_1-logloss:0.25495
# [195]	validation_0-logloss:0.25277	validation_1-logloss:0.25474
# [196]	validation_0-logloss:0.25255	validation_1-logloss:0.25453
# [197]	validation_0-logloss:0.25233	validation_1-logloss:0.25431
# [198]	validation_0-logloss:0.25212	validation_1-logloss:0.25410
# [199]	validation_0-logloss:0.25191	validation_1-logloss:0.25390
# [200]	validation_0-logloss:0.25170	validation_1-logloss:0.25370
# [201]	validation_0-logloss:0.25149	validation_1-logloss:0.25350
# [202]	validation_0-logloss:0.25129	validation_1-logloss:0.25330
# [203]	validation_0-logloss:0.25109	validation_1-logloss:0.25311
# [204]	validation_0-logloss:0.25089	validation_1-logloss:0.25291
# [205]	validation_0-logloss:0.25070	validation_1-logloss:0.25273
# [206]	validation_0-logloss:0.25051	validation_1-logloss:0.25254
# [207]	validation_0-logloss:0.25031	validation_1-logloss:0.25236
# [208]	validation_0-logloss:0.25013	validation_1-logloss:0.25217
# [209]	validation_0-logloss:0.24994	validation_1-logloss:0.25199
# [210]	validation_0-logloss:0.24976	validation_1-logloss:0.25181
# [211]	validation_0-logloss:0.24958	validation_1-logloss:0.25164
# [212]	validation_0-logloss:0.24940	validation_1-logloss:0.25146
# [213]	validation_0-logloss:0.24922	validation_1-logloss:0.25129
# [214]	validation_0-logloss:0.24904	validation_1-logloss:0.25111
# [215]	validation_0-logloss:0.24887	validation_1-logloss:0.25095
# [216]	validation_0-logloss:0.24869	validation_1-logloss:0.25078
# [217]	validation_0-logloss:0.24853	validation_1-logloss:0.25062
# [218]	validation_0-logloss:0.24836	validation_1-logloss:0.25046
# [219]	validation_0-logloss:0.24820	validation_1-logloss:0.25030
# [220]	validation_0-logloss:0.24803	validation_1-logloss:0.25014
# [221]	validation_0-logloss:0.24787	validation_1-logloss:0.24999
# [222]	validation_0-logloss:0.24772	validation_1-logloss:0.24984
# [223]	validation_0-logloss:0.24756	validation_1-logloss:0.24969
# [224]	validation_0-logloss:0.24741	validation_1-logloss:0.24954
# [225]	validation_0-logloss:0.24726	validation_1-logloss:0.24939
# [226]	validation_0-logloss:0.24711	validation_1-logloss:0.24925
# [227]	validation_0-logloss:0.24696	validation_1-logloss:0.24910
# [228]	validation_0-logloss:0.24681	validation_1-logloss:0.24897
# [229]	validation_0-logloss:0.24667	validation_1-logloss:0.24883
# [230]	validation_0-logloss:0.24652	validation_1-logloss:0.24869
# [231]	validation_0-logloss:0.24638	validation_1-logloss:0.24855
# [232]	validation_0-logloss:0.24624	validation_1-logloss:0.24842
# [233]	validation_0-logloss:0.24610	validation_1-logloss:0.24828
# [234]	validation_0-logloss:0.24596	validation_1-logloss:0.24815
# [235]	validation_0-logloss:0.24583	validation_1-logloss:0.24802
# [236]	validation_0-logloss:0.24569	validation_1-logloss:0.24789
# [237]	validation_0-logloss:0.24556	validation_1-logloss:0.24776
# [238]	validation_0-logloss:0.24543	validation_1-logloss:0.24764
# [239]	validation_0-logloss:0.24530	validation_1-logloss:0.24751
# [240]	validation_0-logloss:0.24517	validation_1-logloss:0.24739
# [241]	validation_0-logloss:0.24505	validation_1-logloss:0.24727
# [242]	validation_0-logloss:0.24492	validation_1-logloss:0.24715
# [243]	validation_0-logloss:0.24480	validation_1-logloss:0.24703
# [244]	validation_0-logloss:0.24468	validation_1-logloss:0.24692
# [245]	validation_0-logloss:0.24456	validation_1-logloss:0.24680
# [246]	validation_0-logloss:0.24444	validation_1-logloss:0.24669
# [247]	validation_0-logloss:0.24433	validation_1-logloss:0.24658
# [248]	validation_0-logloss:0.24421	validation_1-logloss:0.24647
# [249]	validation_0-logloss:0.24410	validation_1-logloss:0.24636
# [250]	validation_0-logloss:0.24398	validation_1-logloss:0.24624
# [251]	validation_0-logloss:0.24387	validation_1-logloss:0.24614
# [252]	validation_0-logloss:0.24376	validation_1-logloss:0.24604
# [253]	validation_0-logloss:0.24365	validation_1-logloss:0.24593
# [254]	validation_0-logloss:0.24355	validation_1-logloss:0.24583
# [255]	validation_0-logloss:0.24344	validation_1-logloss:0.24573
# [256]	validation_0-logloss:0.24333	validation_1-logloss:0.24563
# [257]	validation_0-logloss:0.24323	validation_1-logloss:0.24553
# [258]	validation_0-logloss:0.24313	validation_1-logloss:0.24543
# [259]	validation_0-logloss:0.24302	validation_1-logloss:0.24534
# [260]	validation_0-logloss:0.24292	validation_1-logloss:0.24524
# [261]	validation_0-logloss:0.24282	validation_1-logloss:0.24514
# [262]	validation_0-logloss:0.24273	validation_1-logloss:0.24505
# [263]	validation_0-logloss:0.24263	validation_1-logloss:0.24496
# [264]	validation_0-logloss:0.24254	validation_1-logloss:0.24487
# [265]	validation_0-logloss:0.24244	validation_1-logloss:0.24478
# [266]	validation_0-logloss:0.24234	validation_1-logloss:0.24468
# [267]	validation_0-logloss:0.24225	validation_1-logloss:0.24460
# [268]	validation_0-logloss:0.24216	validation_1-logloss:0.24451
# [269]	validation_0-logloss:0.24207	validation_1-logloss:0.24442
# [270]	validation_0-logloss:0.24198	validation_1-logloss:0.24433
# [271]	validation_0-logloss:0.24189	validation_1-logloss:0.24425
# [272]	validation_0-logloss:0.24180	validation_1-logloss:0.24417
# [273]	validation_0-logloss:0.24172	validation_1-logloss:0.24409
# [274]	validation_0-logloss:0.24163	validation_1-logloss:0.24401
# [275]	validation_0-logloss:0.24155	validation_1-logloss:0.24393
# [276]	validation_0-logloss:0.24147	validation_1-logloss:0.24385
# [277]	validation_0-logloss:0.24138	validation_1-logloss:0.24377
# [278]	validation_0-logloss:0.24130	validation_1-logloss:0.24370
# [279]	validation_0-logloss:0.24122	validation_1-logloss:0.24362
# [280]	validation_0-logloss:0.24114	validation_1-logloss:0.24354
# [281]	validation_0-logloss:0.24107	validation_1-logloss:0.24347
# [282]	validation_0-logloss:0.24099	validation_1-logloss:0.24340
# [283]	validation_0-logloss:0.24091	validation_1-logloss:0.24333
# [284]	validation_0-logloss:0.24084	validation_1-logloss:0.24326
# [285]	validation_0-logloss:0.24076	validation_1-logloss:0.24319
# [286]	validation_0-logloss:0.24069	validation_1-logloss:0.24312
# [287]	validation_0-logloss:0.24061	validation_1-logloss:0.24305
# [288]	validation_0-logloss:0.24054	validation_1-logloss:0.24298
# [289]	validation_0-logloss:0.24047	validation_1-logloss:0.24291
# [290]	validation_0-logloss:0.24040	validation_1-logloss:0.24285
# [291]	validation_0-logloss:0.24033	validation_1-logloss:0.24278
# [292]	validation_0-logloss:0.24026	validation_1-logloss:0.24272
# [293]	validation_0-logloss:0.24019	validation_1-logloss:0.24266
# [294]	validation_0-logloss:0.24012	validation_1-logloss:0.24259
# [295]	validation_0-logloss:0.24005	validation_1-logloss:0.24253
# [296]	validation_0-logloss:0.23999	validation_1-logloss:0.24247
# [297]	validation_0-logloss:0.23992	validation_1-logloss:0.24241
# [298]	validation_0-logloss:0.23985	validation_1-logloss:0.24234
# [299]	validation_0-logloss:0.23979	validation_1-logloss:0.24229
# [300]	validation_0-logloss:0.23973	validation_1-logloss:0.24223
# [301]	validation_0-logloss:0.23966	validation_1-logloss:0.24217
# [302]	validation_0-logloss:0.23960	validation_1-logloss:0.24211
# [303]	validation_0-logloss:0.23954	validation_1-logloss:0.24205
# [304]	validation_0-logloss:0.23948	validation_1-logloss:0.24200
# [305]	validation_0-logloss:0.23941	validation_1-logloss:0.24194
# [306]	validation_0-logloss:0.23935	validation_1-logloss:0.24189
# [307]	validation_0-logloss:0.23929	validation_1-logloss:0.24183
# [308]	validation_0-logloss:0.23923	validation_1-logloss:0.24178
# [309]	validation_0-logloss:0.23918	validation_1-logloss:0.24173
# [310]	validation_0-logloss:0.23912	validation_1-logloss:0.24167
# [311]	validation_0-logloss:0.23906	validation_1-logloss:0.24162
# [312]	validation_0-logloss:0.23900	validation_1-logloss:0.24157
# [313]	validation_0-logloss:0.23895	validation_1-logloss:0.24151
# [314]	validation_0-logloss:0.23889	validation_1-logloss:0.24147
# [315]	validation_0-logloss:0.23884	validation_1-logloss:0.24141
# [316]	validation_0-logloss:0.23878	validation_1-logloss:0.24136
# [317]	validation_0-logloss:0.23873	validation_1-logloss:0.24132
# [318]	validation_0-logloss:0.23868	validation_1-logloss:0.24127
# [319]	validation_0-logloss:0.23862	validation_1-logloss:0.24122
# [320]	validation_0-logloss:0.23857	validation_1-logloss:0.24117
# [321]	validation_0-logloss:0.23852	validation_1-logloss:0.24112
# [322]	validation_0-logloss:0.23847	validation_1-logloss:0.24107
# [323]	validation_0-logloss:0.23842	validation_1-logloss:0.24103
# [324]	validation_0-logloss:0.23837	validation_1-logloss:0.24098
# [325]	validation_0-logloss:0.23831	validation_1-logloss:0.24093
# [326]	validation_0-logloss:0.23826	validation_1-logloss:0.24089
# [327]	validation_0-logloss:0.23822	validation_1-logloss:0.24084
# [328]	validation_0-logloss:0.23817	validation_1-logloss:0.24080
# [329]	validation_0-logloss:0.23812	validation_1-logloss:0.24075
# [330]	validation_0-logloss:0.23807	validation_1-logloss:0.24071
# [331]	validation_0-logloss:0.23802	validation_1-logloss:0.24067
# [332]	validation_0-logloss:0.23798	validation_1-logloss:0.24062
# [333]	validation_0-logloss:0.23793	validation_1-logloss:0.24058
# [334]	validation_0-logloss:0.23789	validation_1-logloss:0.24054
# [335]	validation_0-logloss:0.23784	validation_1-logloss:0.24050
# [336]	validation_0-logloss:0.23780	validation_1-logloss:0.24046
# [337]	validation_0-logloss:0.23775	validation_1-logloss:0.24042
# [338]	validation_0-logloss:0.23771	validation_1-logloss:0.24038
# [339]	validation_0-logloss:0.23767	validation_1-logloss:0.24034
# [340]	validation_0-logloss:0.23762	validation_1-logloss:0.24030
# [341]	validation_0-logloss:0.23758	validation_1-logloss:0.24026
# [342]	validation_0-logloss:0.23753	validation_1-logloss:0.24022
# [343]	validation_0-logloss:0.23749	validation_1-logloss:0.24018
# [344]	validation_0-logloss:0.23745	validation_1-logloss:0.24014
# [345]	validation_0-logloss:0.23741	validation_1-logloss:0.24010
# [346]	validation_0-logloss:0.23737	validation_1-logloss:0.24007
# [347]	validation_0-logloss:0.23732	validation_1-logloss:0.24003
# [348]	validation_0-logloss:0.23729	validation_1-logloss:0.24000
# [349]	validation_0-logloss:0.23725	validation_1-logloss:0.23996
# [350]	validation_0-logloss:0.23721	validation_1-logloss:0.23993
# [351]	validation_0-logloss:0.23717	validation_1-logloss:0.23989
# [352]	validation_0-logloss:0.23713	validation_1-logloss:0.23986
# [353]	validation_0-logloss:0.23709	validation_1-logloss:0.23983
# [354]	validation_0-logloss:0.23705	validation_1-logloss:0.23979
# [355]	validation_0-logloss:0.23701	validation_1-logloss:0.23976
# [356]	validation_0-logloss:0.23697	validation_1-logloss:0.23973
# [357]	validation_0-logloss:0.23694	validation_1-logloss:0.23969
# [358]	validation_0-logloss:0.23690	validation_1-logloss:0.23966
# [359]	validation_0-logloss:0.23686	validation_1-logloss:0.23963
# [360]	validation_0-logloss:0.23683	validation_1-logloss:0.23960
# [361]	validation_0-logloss:0.23679	validation_1-logloss:0.23957
# [362]	validation_0-logloss:0.23676	validation_1-logloss:0.23953
# [363]	validation_0-logloss:0.23672	validation_1-logloss:0.23951
# [364]	validation_0-logloss:0.23669	validation_1-logloss:0.23947
# [365]	validation_0-logloss:0.23665	validation_1-logloss:0.23944
# [366]	validation_0-logloss:0.23662	validation_1-logloss:0.23941
# [367]	validation_0-logloss:0.23658	validation_1-logloss:0.23938
# [368]	validation_0-logloss:0.23655	validation_1-logloss:0.23935
# [369]	validation_0-logloss:0.23651	validation_1-logloss:0.23932
# [370]	validation_0-logloss:0.23648	validation_1-logloss:0.23929
# [371]	validation_0-logloss:0.23645	validation_1-logloss:0.23926
# [372]	validation_0-logloss:0.23641	validation_1-logloss:0.23923
# [373]	validation_0-logloss:0.23638	validation_1-logloss:0.23920
# [374]	validation_0-logloss:0.23635	validation_1-logloss:0.23917
# [375]	validation_0-logloss:0.23632	validation_1-logloss:0.23915
# [376]	validation_0-logloss:0.23629	validation_1-logloss:0.23912
# [377]	validation_0-logloss:0.23625	validation_1-logloss:0.23910
# [378]	validation_0-logloss:0.23622	validation_1-logloss:0.23907
# [379]	validation_0-logloss:0.23619	validation_1-logloss:0.23904
# [380]	validation_0-logloss:0.23616	validation_1-logloss:0.23902
# [381]	validation_0-logloss:0.23613	validation_1-logloss:0.23899
# [382]	validation_0-logloss:0.23610	validation_1-logloss:0.23897
# [383]	validation_0-logloss:0.23607	validation_1-logloss:0.23895
# [384]	validation_0-logloss:0.23604	validation_1-logloss:0.23892
# [385]	validation_0-logloss:0.23601	validation_1-logloss:0.23889
# [386]	validation_0-logloss:0.23598	validation_1-logloss:0.23886
# [387]	validation_0-logloss:0.23595	validation_1-logloss:0.23884
# [388]	validation_0-logloss:0.23592	validation_1-logloss:0.23882
# [389]	validation_0-logloss:0.23589	validation_1-logloss:0.23879
# [390]	validation_0-logloss:0.23586	validation_1-logloss:0.23877
# [391]	validation_0-logloss:0.23583	validation_1-logloss:0.23874
# [392]	validation_0-logloss:0.23581	validation_1-logloss:0.23872
# [393]	validation_0-logloss:0.23578	validation_1-logloss:0.23870
# [394]	validation_0-logloss:0.23575	validation_1-logloss:0.23867
# [395]	validation_0-logloss:0.23573	validation_1-logloss:0.23865
# [396]	validation_0-logloss:0.23570	validation_1-logloss:0.23863
# [397]	validation_0-logloss:0.23567	validation_1-logloss:0.23860
# [398]	validation_0-logloss:0.23564	validation_1-logloss:0.23858
# [399]	validation_0-logloss:0.23562	validation_1-logloss:0.23856
# [400]	validation_0-logloss:0.23559	validation_1-logloss:0.23854
# [401]	validation_0-logloss:0.23556	validation_1-logloss:0.23851
# [402]	validation_0-logloss:0.23554	validation_1-logloss:0.23849
# [403]	validation_0-logloss:0.23551	validation_1-logloss:0.23847
# [404]	validation_0-logloss:0.23548	validation_1-logloss:0.23845
# [405]	validation_0-logloss:0.23546	validation_1-logloss:0.23843
# [406]	validation_0-logloss:0.23543	validation_1-logloss:0.23841
# [407]	validation_0-logloss:0.23540	validation_1-logloss:0.23838
# [408]	validation_0-logloss:0.23538	validation_1-logloss:0.23836
# [409]	validation_0-logloss:0.23535	validation_1-logloss:0.23834
# [410]	validation_0-logloss:0.23533	validation_1-logloss:0.23832
# [411]	validation_0-logloss:0.23531	validation_1-logloss:0.23830
# [412]	validation_0-logloss:0.23528	validation_1-logloss:0.23828
# [413]	validation_0-logloss:0.23526	validation_1-logloss:0.23826
# [414]	validation_0-logloss:0.23523	validation_1-logloss:0.23824
# [415]	validation_0-logloss:0.23521	validation_1-logloss:0.23822
# [416]	validation_0-logloss:0.23519	validation_1-logloss:0.23820
# [417]	validation_0-logloss:0.23516	validation_1-logloss:0.23819
# [418]	validation_0-logloss:0.23514	validation_1-logloss:0.23816
# [419]	validation_0-logloss:0.23512	validation_1-logloss:0.23814
# [420]	validation_0-logloss:0.23509	validation_1-logloss:0.23813
# [421]	validation_0-logloss:0.23507	validation_1-logloss:0.23811
# [422]	validation_0-logloss:0.23505	validation_1-logloss:0.23809
# [423]	validation_0-logloss:0.23503	validation_1-logloss:0.23807
# [424]	validation_0-logloss:0.23500	validation_1-logloss:0.23805
# [425]	validation_0-logloss:0.23498	validation_1-logloss:0.23804
# [426]	validation_0-logloss:0.23496	validation_1-logloss:0.23802
# [427]	validation_0-logloss:0.23494	validation_1-logloss:0.23800
# [428]	validation_0-logloss:0.23492	validation_1-logloss:0.23798
# [429]	validation_0-logloss:0.23490	validation_1-logloss:0.23797
# [430]	validation_0-logloss:0.23488	validation_1-logloss:0.23795
# [431]	validation_0-logloss:0.23485	validation_1-logloss:0.23793
# [432]	validation_0-logloss:0.23483	validation_1-logloss:0.23791
# [433]	validation_0-logloss:0.23481	validation_1-logloss:0.23790
# [434]	validation_0-logloss:0.23479	validation_1-logloss:0.23788
# [435]	validation_0-logloss:0.23477	validation_1-logloss:0.23787
# [436]	validation_0-logloss:0.23475	validation_1-logloss:0.23785
# [437]	validation_0-logloss:0.23473	validation_1-logloss:0.23783
# [438]	validation_0-logloss:0.23471	validation_1-logloss:0.23781
# [439]	validation_0-logloss:0.23469	validation_1-logloss:0.23780
# [440]	validation_0-logloss:0.23467	validation_1-logloss:0.23778
# [441]	validation_0-logloss:0.23465	validation_1-logloss:0.23777
# [442]	validation_0-logloss:0.23463	validation_1-logloss:0.23776
# [443]	validation_0-logloss:0.23461	validation_1-logloss:0.23774
# [444]	validation_0-logloss:0.23459	validation_1-logloss:0.23772
# [445]	validation_0-logloss:0.23457	validation_1-logloss:0.23771
# [446]	validation_0-logloss:0.23455	validation_1-logloss:0.23769
# [447]	validation_0-logloss:0.23453	validation_1-logloss:0.23768
# [448]	validation_0-logloss:0.23451	validation_1-logloss:0.23766
# [449]	validation_0-logloss:0.23449	validation_1-logloss:0.23765
# [450]	validation_0-logloss:0.23447	validation_1-logloss:0.23763
# [451]	validation_0-logloss:0.23446	validation_1-logloss:0.23762
# [452]	validation_0-logloss:0.23444	validation_1-logloss:0.23761
# [453]	validation_0-logloss:0.23442	validation_1-logloss:0.23759
# [454]	validation_0-logloss:0.23440	validation_1-logloss:0.23757
# [455]	validation_0-logloss:0.23438	validation_1-logloss:0.23756
# [456]	validation_0-logloss:0.23436	validation_1-logloss:0.23755
# [457]	validation_0-logloss:0.23434	validation_1-logloss:0.23753
# [458]	validation_0-logloss:0.23433	validation_1-logloss:0.23752
# [459]	validation_0-logloss:0.23431	validation_1-logloss:0.23750
# [460]	validation_0-logloss:0.23429	validation_1-logloss:0.23749
# [461]	validation_0-logloss:0.23427	validation_1-logloss:0.23748
# [462]	validation_0-logloss:0.23425	validation_1-logloss:0.23746
# [463]	validation_0-logloss:0.23424	validation_1-logloss:0.23745
# [464]	validation_0-logloss:0.23422	validation_1-logloss:0.23744
# [465]	validation_0-logloss:0.23420	validation_1-logloss:0.23742
# [466]	validation_0-logloss:0.23418	validation_1-logloss:0.23741
# [467]	validation_0-logloss:0.23416	validation_1-logloss:0.23740
# [468]	validation_0-logloss:0.23415	validation_1-logloss:0.23738
# [469]	validation_0-logloss:0.23413	validation_1-logloss:0.23737
# [470]	validation_0-logloss:0.23411	validation_1-logloss:0.23736
# [471]	validation_0-logloss:0.23410	validation_1-logloss:0.23735
# [472]	validation_0-logloss:0.23408	validation_1-logloss:0.23733
# [473]	validation_0-logloss:0.23406	validation_1-logloss:0.23732
# [474]	validation_0-logloss:0.23404	validation_1-logloss:0.23731
# [475]	validation_0-logloss:0.23403	validation_1-logloss:0.23730
# [476]	validation_0-logloss:0.23401	validation_1-logloss:0.23728
# [477]	validation_0-logloss:0.23400	validation_1-logloss:0.23727
# [478]	validation_0-logloss:0.23398	validation_1-logloss:0.23726
# [479]	validation_0-logloss:0.23397	validation_1-logloss:0.23725
# [480]	validation_0-logloss:0.23395	validation_1-logloss:0.23723
# [481]	validation_0-logloss:0.23393	validation_1-logloss:0.23722
# [482]	validation_0-logloss:0.23392	validation_1-logloss:0.23721
# [483]	validation_0-logloss:0.23390	validation_1-logloss:0.23720
# [484]	validation_0-logloss:0.23389	validation_1-logloss:0.23719
# [485]	validation_0-logloss:0.23387	validation_1-logloss:0.23718
# [486]	validation_0-logloss:0.23386	validation_1-logloss:0.23717
# [487]	validation_0-logloss:0.23384	validation_1-logloss:0.23716
# [488]	validation_0-logloss:0.23383	validation_1-logloss:0.23714
# [489]	validation_0-logloss:0.23381	validation_1-logloss:0.23713
# [490]	validation_0-logloss:0.23380	validation_1-logloss:0.23712
# [491]	validation_0-logloss:0.23378	validation_1-logloss:0.23711
# [492]	validation_0-logloss:0.23377	validation_1-logloss:0.23710
# [493]	validation_0-logloss:0.23375	validation_1-logloss:0.23709
# [494]	validation_0-logloss:0.23374	validation_1-logloss:0.23708
# [495]	validation_0-logloss:0.23372	validation_1-logloss:0.23707
# [496]	validation_0-logloss:0.23371	validation_1-logloss:0.23706
# [497]	validation_0-logloss:0.23370	validation_1-logloss:0.23705
# [498]	validation_0-logloss:0.23368	validation_1-logloss:0.23704
# [499]	validation_0-logloss:0.23367	validation_1-logloss:0.23703
# RMSE: 0.1948142355315805
# R²: 0.006621676648340236
# Preprocessing method : Undersampling
# [0]	validation_0-logloss:0.68687	validation_1-logloss:0.68690
# [1]	validation_0-logloss:0.68073	validation_1-logloss:0.68078
# [2]	validation_0-logloss:0.67470	validation_1-logloss:0.67478
# [3]	validation_0-logloss:0.66879	validation_1-logloss:0.66890
# [4]	validation_0-logloss:0.66300	validation_1-logloss:0.66315
# [5]	validation_0-logloss:0.65732	validation_1-logloss:0.65751
# [6]	validation_0-logloss:0.65174	validation_1-logloss:0.65197
# [7]	validation_0-logloss:0.64628	validation_1-logloss:0.64655
# [8]	validation_0-logloss:0.64091	validation_1-logloss:0.64122
# [9]	validation_0-logloss:0.63565	validation_1-logloss:0.63600
# [10]	validation_0-logloss:0.63048	validation_1-logloss:0.63088
# [11]	validation_0-logloss:0.62541	validation_1-logloss:0.62586
# [12]	validation_0-logloss:0.62043	validation_1-logloss:0.62092
# [13]	validation_0-logloss:0.61554	validation_1-logloss:0.61609
# [14]	validation_0-logloss:0.61075	validation_1-logloss:0.61135
# [15]	validation_0-logloss:0.60603	validation_1-logloss:0.60669
# [16]	validation_0-logloss:0.60141	validation_1-logloss:0.60212
# [17]	validation_0-logloss:0.59686	validation_1-logloss:0.59762
# [18]	validation_0-logloss:0.59239	validation_1-logloss:0.59321
# [19]	validation_0-logloss:0.58800	validation_1-logloss:0.58888
# [20]	validation_0-logloss:0.58370	validation_1-logloss:0.58463
# [21]	validation_0-logloss:0.57946	validation_1-logloss:0.58045
# [22]	validation_0-logloss:0.57529	validation_1-logloss:0.57635
# [23]	validation_0-logloss:0.57120	validation_1-logloss:0.57232
# [24]	validation_0-logloss:0.56718	validation_1-logloss:0.56836
# [25]	validation_0-logloss:0.56323	validation_1-logloss:0.56447
# [26]	validation_0-logloss:0.55935	validation_1-logloss:0.56065
# [27]	validation_0-logloss:0.55553	validation_1-logloss:0.55689
# [28]	validation_0-logloss:0.55177	validation_1-logloss:0.55319
# [29]	validation_0-logloss:0.54807	validation_1-logloss:0.54956
# [30]	validation_0-logloss:0.54444	validation_1-logloss:0.54599
# [31]	validation_0-logloss:0.54087	validation_1-logloss:0.54248
# [32]	validation_0-logloss:0.53735	validation_1-logloss:0.53903
# [33]	validation_0-logloss:0.53390	validation_1-logloss:0.53564
# [34]	validation_0-logloss:0.53050	validation_1-logloss:0.53231
# [35]	validation_0-logloss:0.52716	validation_1-logloss:0.52904
# [36]	validation_0-logloss:0.52387	validation_1-logloss:0.52581
# [37]	validation_0-logloss:0.52064	validation_1-logloss:0.52264
# [38]	validation_0-logloss:0.51745	validation_1-logloss:0.51952
# [39]	validation_0-logloss:0.51432	validation_1-logloss:0.51646
# [40]	validation_0-logloss:0.51124	validation_1-logloss:0.51345
# [41]	validation_0-logloss:0.50821	validation_1-logloss:0.51048
# [42]	validation_0-logloss:0.50523	validation_1-logloss:0.50757
# [43]	validation_0-logloss:0.50230	validation_1-logloss:0.50470
# [44]	validation_0-logloss:0.49941	validation_1-logloss:0.50188
# [45]	validation_0-logloss:0.49656	validation_1-logloss:0.49911
# [46]	validation_0-logloss:0.49377	validation_1-logloss:0.49638
# [47]	validation_0-logloss:0.49102	validation_1-logloss:0.49370
# [48]	validation_0-logloss:0.48830	validation_1-logloss:0.49105
# [49]	validation_0-logloss:0.48563	validation_1-logloss:0.48845
# [50]	validation_0-logloss:0.48301	validation_1-logloss:0.48590
# [51]	validation_0-logloss:0.48042	validation_1-logloss:0.48338
# [52]	validation_0-logloss:0.47788	validation_1-logloss:0.48090
# [53]	validation_0-logloss:0.47537	validation_1-logloss:0.47847
# [54]	validation_0-logloss:0.47290	validation_1-logloss:0.47607
# [55]	validation_0-logloss:0.47047	validation_1-logloss:0.47371
# [56]	validation_0-logloss:0.46807	validation_1-logloss:0.47139
# [57]	validation_0-logloss:0.46572	validation_1-logloss:0.46910
# [58]	validation_0-logloss:0.46340	validation_1-logloss:0.46685
# [59]	validation_0-logloss:0.46112	validation_1-logloss:0.46464
# [60]	validation_0-logloss:0.45886	validation_1-logloss:0.46246
# [61]	validation_0-logloss:0.45665	validation_1-logloss:0.46031
# [62]	validation_0-logloss:0.45446	validation_1-logloss:0.45820
# [63]	validation_0-logloss:0.45231	validation_1-logloss:0.45612
# [64]	validation_0-logloss:0.45019	validation_1-logloss:0.45407
# [65]	validation_0-logloss:0.44811	validation_1-logloss:0.45205
# [66]	validation_0-logloss:0.44605	validation_1-logloss:0.45007
# [67]	validation_0-logloss:0.44403	validation_1-logloss:0.44812
# [68]	validation_0-logloss:0.44204	validation_1-logloss:0.44620
# [69]	validation_0-logloss:0.44007	validation_1-logloss:0.44430
# [70]	validation_0-logloss:0.43813	validation_1-logloss:0.44243
# [71]	validation_0-logloss:0.43622	validation_1-logloss:0.44059
# [72]	validation_0-logloss:0.43435	validation_1-logloss:0.43878
# [73]	validation_0-logloss:0.43250	validation_1-logloss:0.43700
# [74]	validation_0-logloss:0.43067	validation_1-logloss:0.43524
# [75]	validation_0-logloss:0.42887	validation_1-logloss:0.43351
# [76]	validation_0-logloss:0.42709	validation_1-logloss:0.43181
# [77]	validation_0-logloss:0.42534	validation_1-logloss:0.43013
# [78]	validation_0-logloss:0.42363	validation_1-logloss:0.42848
# [79]	validation_0-logloss:0.42193	validation_1-logloss:0.42685
# [80]	validation_0-logloss:0.42026	validation_1-logloss:0.42525
# [81]	validation_0-logloss:0.41861	validation_1-logloss:0.42367
# [82]	validation_0-logloss:0.41699	validation_1-logloss:0.42211
# [83]	validation_0-logloss:0.41539	validation_1-logloss:0.42059
# [84]	validation_0-logloss:0.41381	validation_1-logloss:0.41908
# [85]	validation_0-logloss:0.41226	validation_1-logloss:0.41759
# [86]	validation_0-logloss:0.41073	validation_1-logloss:0.41613
# [87]	validation_0-logloss:0.40922	validation_1-logloss:0.41468
# [88]	validation_0-logloss:0.40774	validation_1-logloss:0.41327
# [89]	validation_0-logloss:0.40627	validation_1-logloss:0.41187
# [90]	validation_0-logloss:0.40483	validation_1-logloss:0.41049
# [91]	validation_0-logloss:0.40340	validation_1-logloss:0.40913
# [92]	validation_0-logloss:0.40200	validation_1-logloss:0.40780
# [93]	validation_0-logloss:0.40062	validation_1-logloss:0.40649
# [94]	validation_0-logloss:0.39926	validation_1-logloss:0.40519
# [95]	validation_0-logloss:0.39791	validation_1-logloss:0.40391
# [96]	validation_0-logloss:0.39659	validation_1-logloss:0.40265
# [97]	validation_0-logloss:0.39528	validation_1-logloss:0.40141
# [98]	validation_0-logloss:0.39400	validation_1-logloss:0.40019
# [99]	validation_0-logloss:0.39273	validation_1-logloss:0.39898
# [100]	validation_0-logloss:0.39148	validation_1-logloss:0.39780
# [101]	validation_0-logloss:0.39024	validation_1-logloss:0.39663
# [102]	validation_0-logloss:0.38903	validation_1-logloss:0.39548
# [103]	validation_0-logloss:0.38782	validation_1-logloss:0.39435
# [104]	validation_0-logloss:0.38664	validation_1-logloss:0.39323
# [105]	validation_0-logloss:0.38548	validation_1-logloss:0.39213
# [106]	validation_0-logloss:0.38433	validation_1-logloss:0.39104
# [107]	validation_0-logloss:0.38319	validation_1-logloss:0.38997
# [108]	validation_0-logloss:0.38208	validation_1-logloss:0.38892
# [109]	validation_0-logloss:0.38098	validation_1-logloss:0.38788
# [110]	validation_0-logloss:0.37989	validation_1-logloss:0.38685
# [111]	validation_0-logloss:0.37882	validation_1-logloss:0.38585
# [112]	validation_0-logloss:0.37777	validation_1-logloss:0.38485
# [113]	validation_0-logloss:0.37672	validation_1-logloss:0.38387
# [114]	validation_0-logloss:0.37570	validation_1-logloss:0.38291
# [115]	validation_0-logloss:0.37468	validation_1-logloss:0.38196
# [116]	validation_0-logloss:0.37369	validation_1-logloss:0.38102
# [117]	validation_0-logloss:0.37270	validation_1-logloss:0.38010
# [118]	validation_0-logloss:0.37173	validation_1-logloss:0.37919
# [119]	validation_0-logloss:0.37077	validation_1-logloss:0.37829
# [120]	validation_0-logloss:0.36983	validation_1-logloss:0.37740
# [121]	validation_0-logloss:0.36889	validation_1-logloss:0.37653
# [122]	validation_0-logloss:0.36798	validation_1-logloss:0.37568
# [123]	validation_0-logloss:0.36707	validation_1-logloss:0.37483
# [124]	validation_0-logloss:0.36618	validation_1-logloss:0.37400
# [125]	validation_0-logloss:0.36530	validation_1-logloss:0.37318
# [126]	validation_0-logloss:0.36443	validation_1-logloss:0.37236
# [127]	validation_0-logloss:0.36358	validation_1-logloss:0.37157
# [128]	validation_0-logloss:0.36273	validation_1-logloss:0.37078
# [129]	validation_0-logloss:0.36190	validation_1-logloss:0.37001
# [130]	validation_0-logloss:0.36108	validation_1-logloss:0.36923
# [131]	validation_0-logloss:0.36027	validation_1-logloss:0.36849
# [132]	validation_0-logloss:0.35947	validation_1-logloss:0.36774
# [133]	validation_0-logloss:0.35869	validation_1-logloss:0.36701
# [134]	validation_0-logloss:0.35791	validation_1-logloss:0.36629
# [135]	validation_0-logloss:0.35714	validation_1-logloss:0.36558
# [136]	validation_0-logloss:0.35638	validation_1-logloss:0.36488
# [137]	validation_0-logloss:0.35564	validation_1-logloss:0.36419
# [138]	validation_0-logloss:0.35490	validation_1-logloss:0.36350
# [139]	validation_0-logloss:0.35418	validation_1-logloss:0.36283
# [140]	validation_0-logloss:0.35346	validation_1-logloss:0.36217
# [141]	validation_0-logloss:0.35275	validation_1-logloss:0.36152
# [142]	validation_0-logloss:0.35206	validation_1-logloss:0.36088
# [143]	validation_0-logloss:0.35137	validation_1-logloss:0.36024
# [144]	validation_0-logloss:0.35069	validation_1-logloss:0.35961
# [145]	validation_0-logloss:0.35002	validation_1-logloss:0.35900
# [146]	validation_0-logloss:0.34936	validation_1-logloss:0.35839
# [147]	validation_0-logloss:0.34871	validation_1-logloss:0.35779
# [148]	validation_0-logloss:0.34807	validation_1-logloss:0.35720
# [149]	validation_0-logloss:0.34743	validation_1-logloss:0.35661
# [150]	validation_0-logloss:0.34681	validation_1-logloss:0.35604
# [151]	validation_0-logloss:0.34619	validation_1-logloss:0.35547
# [152]	validation_0-logloss:0.34559	validation_1-logloss:0.35491
# [153]	validation_0-logloss:0.34498	validation_1-logloss:0.35436
# [154]	validation_0-logloss:0.34439	validation_1-logloss:0.35382
# [155]	validation_0-logloss:0.34381	validation_1-logloss:0.35328
# [156]	validation_0-logloss:0.34323	validation_1-logloss:0.35276
# [157]	validation_0-logloss:0.34266	validation_1-logloss:0.35224
# [158]	validation_0-logloss:0.34210	validation_1-logloss:0.35172
# [159]	validation_0-logloss:0.34155	validation_1-logloss:0.35122
# [160]	validation_0-logloss:0.34100	validation_1-logloss:0.35072
# [161]	validation_0-logloss:0.34046	validation_1-logloss:0.35023
# [162]	validation_0-logloss:0.33993	validation_1-logloss:0.34975
# [163]	validation_0-logloss:0.33941	validation_1-logloss:0.34928
# [164]	validation_0-logloss:0.33889	validation_1-logloss:0.34881
# [165]	validation_0-logloss:0.33838	validation_1-logloss:0.34835
# [166]	validation_0-logloss:0.33788	validation_1-logloss:0.34789
# [167]	validation_0-logloss:0.33738	validation_1-logloss:0.34744
# [168]	validation_0-logloss:0.33689	validation_1-logloss:0.34700
# [169]	validation_0-logloss:0.33641	validation_1-logloss:0.34656
# [170]	validation_0-logloss:0.33593	validation_1-logloss:0.34613
# [171]	validation_0-logloss:0.33546	validation_1-logloss:0.34571
# [172]	validation_0-logloss:0.33500	validation_1-logloss:0.34529
# [173]	validation_0-logloss:0.33454	validation_1-logloss:0.34488
# [174]	validation_0-logloss:0.33409	validation_1-logloss:0.34447
# [175]	validation_0-logloss:0.33364	validation_1-logloss:0.34407
# [176]	validation_0-logloss:0.33320	validation_1-logloss:0.34367
# [177]	validation_0-logloss:0.33276	validation_1-logloss:0.34328
# [178]	validation_0-logloss:0.33234	validation_1-logloss:0.34290
# [179]	validation_0-logloss:0.33191	validation_1-logloss:0.34252
# [180]	validation_0-logloss:0.33150	validation_1-logloss:0.34215
# [181]	validation_0-logloss:0.33108	validation_1-logloss:0.34177
# [182]	validation_0-logloss:0.33068	validation_1-logloss:0.34142
# [183]	validation_0-logloss:0.33028	validation_1-logloss:0.34106
# [184]	validation_0-logloss:0.32988	validation_1-logloss:0.34071
# [185]	validation_0-logloss:0.32949	validation_1-logloss:0.34036
# [186]	validation_0-logloss:0.32911	validation_1-logloss:0.34001
# [187]	validation_0-logloss:0.32873	validation_1-logloss:0.33968
# [188]	validation_0-logloss:0.32836	validation_1-logloss:0.33934
# [189]	validation_0-logloss:0.32798	validation_1-logloss:0.33901
# [190]	validation_0-logloss:0.32762	validation_1-logloss:0.33869
# [191]	validation_0-logloss:0.32726	validation_1-logloss:0.33837
# [192]	validation_0-logloss:0.32690	validation_1-logloss:0.33806
# [193]	validation_0-logloss:0.32655	validation_1-logloss:0.33775
# [194]	validation_0-logloss:0.32620	validation_1-logloss:0.33744
# [195]	validation_0-logloss:0.32586	validation_1-logloss:0.33714
# [196]	validation_0-logloss:0.32552	validation_1-logloss:0.33684
# [197]	validation_0-logloss:0.32519	validation_1-logloss:0.33655
# [198]	validation_0-logloss:0.32486	validation_1-logloss:0.33627
# [199]	validation_0-logloss:0.32454	validation_1-logloss:0.33598
# [200]	validation_0-logloss:0.32422	validation_1-logloss:0.33570
# [201]	validation_0-logloss:0.32390	validation_1-logloss:0.33542
# [202]	validation_0-logloss:0.32359	validation_1-logloss:0.33515
# [203]	validation_0-logloss:0.32329	validation_1-logloss:0.33488
# [204]	validation_0-logloss:0.32298	validation_1-logloss:0.33461
# [205]	validation_0-logloss:0.32268	validation_1-logloss:0.33435
# [206]	validation_0-logloss:0.32239	validation_1-logloss:0.33410
# [207]	validation_0-logloss:0.32210	validation_1-logloss:0.33384
# [208]	validation_0-logloss:0.32181	validation_1-logloss:0.33359
# [209]	validation_0-logloss:0.32153	validation_1-logloss:0.33334
# [210]	validation_0-logloss:0.32125	validation_1-logloss:0.33310
# [211]	validation_0-logloss:0.32097	validation_1-logloss:0.33286
# [212]	validation_0-logloss:0.32070	validation_1-logloss:0.33262
# [213]	validation_0-logloss:0.32043	validation_1-logloss:0.33239
# [214]	validation_0-logloss:0.32017	validation_1-logloss:0.33216
# [215]	validation_0-logloss:0.31990	validation_1-logloss:0.33193
# [216]	validation_0-logloss:0.31965	validation_1-logloss:0.33170
# [217]	validation_0-logloss:0.31939	validation_1-logloss:0.33148
# [218]	validation_0-logloss:0.31914	validation_1-logloss:0.33126
# [219]	validation_0-logloss:0.31889	validation_1-logloss:0.33104
# [220]	validation_0-logloss:0.31864	validation_1-logloss:0.33083
# [221]	validation_0-logloss:0.31840	validation_1-logloss:0.33062
# [222]	validation_0-logloss:0.31816	validation_1-logloss:0.33042
# [223]	validation_0-logloss:0.31792	validation_1-logloss:0.33021
# [224]	validation_0-logloss:0.31768	validation_1-logloss:0.33001
# [225]	validation_0-logloss:0.31745	validation_1-logloss:0.32981
# [226]	validation_0-logloss:0.31722	validation_1-logloss:0.32962
# [227]	validation_0-logloss:0.31699	validation_1-logloss:0.32943
# [228]	validation_0-logloss:0.31677	validation_1-logloss:0.32924
# [229]	validation_0-logloss:0.31655	validation_1-logloss:0.32905
# [230]	validation_0-logloss:0.31633	validation_1-logloss:0.32887
# [231]	validation_0-logloss:0.31611	validation_1-logloss:0.32869
# [232]	validation_0-logloss:0.31590	validation_1-logloss:0.32851
# [233]	validation_0-logloss:0.31569	validation_1-logloss:0.32833
# [234]	validation_0-logloss:0.31548	validation_1-logloss:0.32816
# [235]	validation_0-logloss:0.31528	validation_1-logloss:0.32798
# [236]	validation_0-logloss:0.31507	validation_1-logloss:0.32781
# [237]	validation_0-logloss:0.31487	validation_1-logloss:0.32765
# [238]	validation_0-logloss:0.31467	validation_1-logloss:0.32747
# [239]	validation_0-logloss:0.31448	validation_1-logloss:0.32731
# [240]	validation_0-logloss:0.31429	validation_1-logloss:0.32715
# [241]	validation_0-logloss:0.31410	validation_1-logloss:0.32699
# [242]	validation_0-logloss:0.31391	validation_1-logloss:0.32684
# [243]	validation_0-logloss:0.31372	validation_1-logloss:0.32668
# [244]	validation_0-logloss:0.31354	validation_1-logloss:0.32652
# [245]	validation_0-logloss:0.31336	validation_1-logloss:0.32637
# [246]	validation_0-logloss:0.31318	validation_1-logloss:0.32622
# [247]	validation_0-logloss:0.31300	validation_1-logloss:0.32607
# [248]	validation_0-logloss:0.31283	validation_1-logloss:0.32592
# [249]	validation_0-logloss:0.31266	validation_1-logloss:0.32578
# [250]	validation_0-logloss:0.31249	validation_1-logloss:0.32564
# ...
# [260]	validation_0-logloss:0.27163	validation_1-logloss:0.30495
# [261]	validation_0-logloss:0.27137	validation_1-logloss:0.30474
# [262]	validation_0-logloss:0.27111	validation_1-logloss:0.30453
# [263]	validation_0-logloss:0.27087	validation_1-logloss:0.30433
# [264]	validation_0-logloss:0.27061	validation_1-logloss:0.30412
# [265]	validation_0-logloss:0.27036	validation_1-logloss:0.30392
# [266]	validation_0-logloss:0.27014	validation_1-logloss:0.30373
# [267]	validation_0-logloss:0.26988	validation_1-logloss:0.30352
# [268]	validation_0-logloss:0.26964	validation_1-logloss:0.30332
# [269]	validation_0-logloss:0.26941	validation_1-logloss:0.30313
# [270]	validation_0-logloss:0.26917	validation_1-logloss:0.30294
# [271]	validation_0-logloss:0.26894	validation_1-logloss:0.30274
# [272]	validation_0-logloss:0.26871	validation_1-logloss:0.30256
# [273]	validation_0-logloss:0.26848	validation_1-logloss:0.30237
# [274]	validation_0-logloss:0.26820	validation_1-logloss:0.30215
# [275]	validation_0-logloss:0.26795	validation_1-logloss:0.30196
# [276]	validation_0-logloss:0.26773	validation_1-logloss:0.30177
# [277]	validation_0-logloss:0.26749	validation_1-logloss:0.30159
# [278]	validation_0-logloss:0.26726	validation_1-logloss:0.30140
# [279]	validation_0-logloss:0.26705	validation_1-logloss:0.30122
# [280]	validation_0-logloss:0.26684	validation_1-logloss:0.30105
# [281]	validation_0-logloss:0.26663	validation_1-logloss:0.30087
# [282]	validation_0-logloss:0.26642	validation_1-logloss:0.30071
# [283]	validation_0-logloss:0.26621	validation_1-logloss:0.30054
# [284]	validation_0-logloss:0.26600	validation_1-logloss:0.30037
# [285]	validation_0-logloss:0.26580	validation_1-logloss:0.30021
# [286]	validation_0-logloss:0.26555	validation_1-logloss:0.30001
# [287]	validation_0-logloss:0.26535	validation_1-logloss:0.29985
# [288]	validation_0-logloss:0.26513	validation_1-logloss:0.29968
# [289]	validation_0-logloss:0.26492	validation_1-logloss:0.29952
# [290]	validation_0-logloss:0.26472	validation_1-logloss:0.29936
# [291]	validation_0-logloss:0.26453	validation_1-logloss:0.29920
# [292]	validation_0-logloss:0.26434	validation_1-logloss:0.29904
# [293]	validation_0-logloss:0.26415	validation_1-logloss:0.29889
# [294]	validation_0-logloss:0.26397	validation_1-logloss:0.29874
# [295]	validation_0-logloss:0.26378	validation_1-logloss:0.29859
# [296]	validation_0-logloss:0.26353	validation_1-logloss:0.29840
# [297]	validation_0-logloss:0.26336	validation_1-logloss:0.29825
# [298]	validation_0-logloss:0.26312	validation_1-logloss:0.29806
# [299]	validation_0-logloss:0.26293	validation_1-logloss:0.29792
# [300]	validation_0-logloss:0.26273	validation_1-logloss:0.29777
# [301]	validation_0-logloss:0.26256	validation_1-logloss:0.29763
# [302]	validation_0-logloss:0.26236	validation_1-logloss:0.29748
# [303]	validation_0-logloss:0.26216	validation_1-logloss:0.29732
# [304]	validation_0-logloss:0.26196	validation_1-logloss:0.29718
# [305]	validation_0-logloss:0.26179	validation_1-logloss:0.29704
# [306]	validation_0-logloss:0.26161	validation_1-logloss:0.29691
# [307]	validation_0-logloss:0.26145	validation_1-logloss:0.29678
# [308]	validation_0-logloss:0.26128	validation_1-logloss:0.29665
# [309]	validation_0-logloss:0.26111	validation_1-logloss:0.29652
# [310]	validation_0-logloss:0.26087	validation_1-logloss:0.29634
# [311]	validation_0-logloss:0.26070	validation_1-logloss:0.29621
# [312]	validation_0-logloss:0.26051	validation_1-logloss:0.29607
# [313]	validation_0-logloss:0.26034	validation_1-logloss:0.29594
# [314]	validation_0-logloss:0.26018	validation_1-logloss:0.29582
# [315]	validation_0-logloss:0.26001	validation_1-logloss:0.29569
# [316]	validation_0-logloss:0.25985	validation_1-logloss:0.29556
# [317]	validation_0-logloss:0.25968	validation_1-logloss:0.29543
# [318]	validation_0-logloss:0.25951	validation_1-logloss:0.29531
# [319]	validation_0-logloss:0.25934	validation_1-logloss:0.29518
# [320]	validation_0-logloss:0.25918	validation_1-logloss:0.29505
# [321]	validation_0-logloss:0.25902	validation_1-logloss:0.29493
# [322]	validation_0-logloss:0.25887	validation_1-logloss:0.29482
# [323]	validation_0-logloss:0.25871	validation_1-logloss:0.29470
# [324]	validation_0-logloss:0.25855	validation_1-logloss:0.29457
# [325]	validation_0-logloss:0.25840	validation_1-logloss:0.29446
# [326]	validation_0-logloss:0.25824	validation_1-logloss:0.29434
# [327]	validation_0-logloss:0.25809	validation_1-logloss:0.29423
# [328]	validation_0-logloss:0.25793	validation_1-logloss:0.29410
# [329]	validation_0-logloss:0.25779	validation_1-logloss:0.29400
# [330]	validation_0-logloss:0.25765	validation_1-logloss:0.29389
# [331]	validation_0-logloss:0.25750	validation_1-logloss:0.29377
# [332]	validation_0-logloss:0.25736	validation_1-logloss:0.29367
# [333]	validation_0-logloss:0.25722	validation_1-logloss:0.29356
# [334]	validation_0-logloss:0.25707	validation_1-logloss:0.29344
# [335]	validation_0-logloss:0.25693	validation_1-logloss:0.29333
# [336]	validation_0-logloss:0.25679	validation_1-logloss:0.29322
# [337]	validation_0-logloss:0.25665	validation_1-logloss:0.29312
# [338]	validation_0-logloss:0.25646	validation_1-logloss:0.29299
# [339]	validation_0-logloss:0.25631	validation_1-logloss:0.29288
# [340]	validation_0-logloss:0.25617	validation_1-logloss:0.29277
# [341]	validation_0-logloss:0.25601	validation_1-logloss:0.29265
# [342]	validation_0-logloss:0.25588	validation_1-logloss:0.29256
# [343]	validation_0-logloss:0.25575	validation_1-logloss:0.29246
# [344]	validation_0-logloss:0.25560	validation_1-logloss:0.29235
# [345]	validation_0-logloss:0.25546	validation_1-logloss:0.29225
# [346]	validation_0-logloss:0.25533	validation_1-logloss:0.29215
# [347]	validation_0-logloss:0.25519	validation_1-logloss:0.29204
# [348]	validation_0-logloss:0.25506	validation_1-logloss:0.29194
# [349]	validation_0-logloss:0.25491	validation_1-logloss:0.29183
# [350]	validation_0-logloss:0.25479	validation_1-logloss:0.29173
# [351]	validation_0-logloss:0.25466	validation_1-logloss:0.29165
# [352]	validation_0-logloss:0.25452	validation_1-logloss:0.29154
# [353]	validation_0-logloss:0.25439	validation_1-logloss:0.29143
# [354]	validation_0-logloss:0.25427	validation_1-logloss:0.29135
# [355]	validation_0-logloss:0.25415	validation_1-logloss:0.29126
# [356]	validation_0-logloss:0.25401	validation_1-logloss:0.29114
# [357]	validation_0-logloss:0.25389	validation_1-logloss:0.29106
# [358]	validation_0-logloss:0.25377	validation_1-logloss:0.29097
# [359]	validation_0-logloss:0.25366	validation_1-logloss:0.29088
# [360]	validation_0-logloss:0.25353	validation_1-logloss:0.29078
# [361]	validation_0-logloss:0.25337	validation_1-logloss:0.29068
# [362]	validation_0-logloss:0.25325	validation_1-logloss:0.29059
# [363]	validation_0-logloss:0.25313	validation_1-logloss:0.29051
# [364]	validation_0-logloss:0.25301	validation_1-logloss:0.29041
# [365]	validation_0-logloss:0.25286	validation_1-logloss:0.29030
# [366]	validation_0-logloss:0.25275	validation_1-logloss:0.29022
# [367]	validation_0-logloss:0.25263	validation_1-logloss:0.29013
# [368]	validation_0-logloss:0.25247	validation_1-logloss:0.29001
# [369]	validation_0-logloss:0.25235	validation_1-logloss:0.28992
# [370]	validation_0-logloss:0.25225	validation_1-logloss:0.28984
# [371]	validation_0-logloss:0.25210	validation_1-logloss:0.28974
# [372]	validation_0-logloss:0.25200	validation_1-logloss:0.28966
# [373]	validation_0-logloss:0.25179	validation_1-logloss:0.28951
# [374]	validation_0-logloss:0.25168	validation_1-logloss:0.28943
# [375]	validation_0-logloss:0.25155	validation_1-logloss:0.28934
# [376]	validation_0-logloss:0.25144	validation_1-logloss:0.28926
# [377]	validation_0-logloss:0.25131	validation_1-logloss:0.28917
# [378]	validation_0-logloss:0.25106	validation_1-logloss:0.28899
# [379]	validation_0-logloss:0.25094	validation_1-logloss:0.28889
# [380]	validation_0-logloss:0.25085	validation_1-logloss:0.28881
# [381]	validation_0-logloss:0.25075	validation_1-logloss:0.28874
# [382]	validation_0-logloss:0.25065	validation_1-logloss:0.28866
# [383]	validation_0-logloss:0.25056	validation_1-logloss:0.28858
# [384]	validation_0-logloss:0.25045	validation_1-logloss:0.28850
# [385]	validation_0-logloss:0.25026	validation_1-logloss:0.28837
# [386]	validation_0-logloss:0.25012	validation_1-logloss:0.28827
# [387]	validation_0-logloss:0.25003	validation_1-logloss:0.28819
# [388]	validation_0-logloss:0.24989	validation_1-logloss:0.28810
# [389]	validation_0-logloss:0.24979	validation_1-logloss:0.28802
# [390]	validation_0-logloss:0.24970	validation_1-logloss:0.28795
# [391]	validation_0-logloss:0.24959	validation_1-logloss:0.28786
# [392]	validation_0-logloss:0.24944	validation_1-logloss:0.28775
# [393]	validation_0-logloss:0.24933	validation_1-logloss:0.28767
# [394]	validation_0-logloss:0.24914	validation_1-logloss:0.28754
# [395]	validation_0-logloss:0.24893	validation_1-logloss:0.28738
# [396]	validation_0-logloss:0.24875	validation_1-logloss:0.28725
# [397]	validation_0-logloss:0.24856	validation_1-logloss:0.28713
# [398]	validation_0-logloss:0.24846	validation_1-logloss:0.28705
# [399]	validation_0-logloss:0.24828	validation_1-logloss:0.28692
# [400]	validation_0-logloss:0.24808	validation_1-logloss:0.28679
# [401]	validation_0-logloss:0.24794	validation_1-logloss:0.28669
# [402]	validation_0-logloss:0.24783	validation_1-logloss:0.28660
# [403]	validation_0-logloss:0.24764	validation_1-logloss:0.28647
# [404]	validation_0-logloss:0.24756	validation_1-logloss:0.28641
# [405]	validation_0-logloss:0.24734	validation_1-logloss:0.28626
# [406]	validation_0-logloss:0.24722	validation_1-logloss:0.28616
# [407]	validation_0-logloss:0.24712	validation_1-logloss:0.28609
# [408]	validation_0-logloss:0.24694	validation_1-logloss:0.28597
# [409]	validation_0-logloss:0.24687	validation_1-logloss:0.28591
# [410]	validation_0-logloss:0.24678	validation_1-logloss:0.28584
# [411]	validation_0-logloss:0.24660	validation_1-logloss:0.28572
# [412]	validation_0-logloss:0.24651	validation_1-logloss:0.28564
# [413]	validation_0-logloss:0.24633	validation_1-logloss:0.28552
# [414]	validation_0-logloss:0.24617	validation_1-logloss:0.28541
# [415]	validation_0-logloss:0.24607	validation_1-logloss:0.28534
# [416]	validation_0-logloss:0.24590	validation_1-logloss:0.28522
# [417]	validation_0-logloss:0.24583	validation_1-logloss:0.28516
# [418]	validation_0-logloss:0.24574	validation_1-logloss:0.28509
# [419]	validation_0-logloss:0.24557	validation_1-logloss:0.28497
# [420]	validation_0-logloss:0.24548	validation_1-logloss:0.28490
# [421]	validation_0-logloss:0.24541	validation_1-logloss:0.28485
# [422]	validation_0-logloss:0.24530	validation_1-logloss:0.28476
# [423]	validation_0-logloss:0.24522	validation_1-logloss:0.28470
# [424]	validation_0-logloss:0.24505	validation_1-logloss:0.28459
# [425]	validation_0-logloss:0.24493	validation_1-logloss:0.28449
# [426]	validation_0-logloss:0.24484	validation_1-logloss:0.28444
# [427]	validation_0-logloss:0.24467	validation_1-logloss:0.28431
# [428]	validation_0-logloss:0.24459	validation_1-logloss:0.28425
# [429]	validation_0-logloss:0.24448	validation_1-logloss:0.28416
# [430]	validation_0-logloss:0.24435	validation_1-logloss:0.28407
# [431]	validation_0-logloss:0.24419	validation_1-logloss:0.28396
# [432]	validation_0-logloss:0.24409	validation_1-logloss:0.28389
# [433]	validation_0-logloss:0.24402	validation_1-logloss:0.28384
# [434]	validation_0-logloss:0.24390	validation_1-logloss:0.28375
# [435]	validation_0-logloss:0.24383	validation_1-logloss:0.28369
# [436]	validation_0-logloss:0.24374	validation_1-logloss:0.28362
# [437]	validation_0-logloss:0.24362	validation_1-logloss:0.28354
# [438]	validation_0-logloss:0.24340	validation_1-logloss:0.28340
# [439]	validation_0-logloss:0.24333	validation_1-logloss:0.28334
# [440]	validation_0-logloss:0.24316	validation_1-logloss:0.28322
# [441]	validation_0-logloss:0.24306	validation_1-logloss:0.28315
# [442]	validation_0-logloss:0.24299	validation_1-logloss:0.28309
# [443]	validation_0-logloss:0.24277	validation_1-logloss:0.28295
# [444]	validation_0-logloss:0.24268	validation_1-logloss:0.28289
# [445]	validation_0-logloss:0.24262	validation_1-logloss:0.28284
# [446]	validation_0-logloss:0.24251	validation_1-logloss:0.28276
# [447]	validation_0-logloss:0.24243	validation_1-logloss:0.28270
# [448]	validation_0-logloss:0.24228	validation_1-logloss:0.28260
# [449]	validation_0-logloss:0.24214	validation_1-logloss:0.28251
# [450]	validation_0-logloss:0.24198	validation_1-logloss:0.28240
# [451]	validation_0-logloss:0.24190	validation_1-logloss:0.28233
# [452]	validation_0-logloss:0.24175	validation_1-logloss:0.28224
# [453]	validation_0-logloss:0.24167	validation_1-logloss:0.28218
# [454]	validation_0-logloss:0.24159	validation_1-logloss:0.28212
# [455]	validation_0-logloss:0.24145	validation_1-logloss:0.28204
# [456]	validation_0-logloss:0.24138	validation_1-logloss:0.28198
# [457]	validation_0-logloss:0.24131	validation_1-logloss:0.28192
# [458]	validation_0-logloss:0.24123	validation_1-logloss:0.28187
# [459]	validation_0-logloss:0.24109	validation_1-logloss:0.28177
# [460]	validation_0-logloss:0.24101	validation_1-logloss:0.28171
# [461]	validation_0-logloss:0.24094	validation_1-logloss:0.28166
# [462]	validation_0-logloss:0.24086	validation_1-logloss:0.28160
# [463]	validation_0-logloss:0.24075	validation_1-logloss:0.28152
# [464]	validation_0-logloss:0.24063	validation_1-logloss:0.28145
# [465]	validation_0-logloss:0.24053	validation_1-logloss:0.28137
# [466]	validation_0-logloss:0.24046	validation_1-logloss:0.28132
# [467]	validation_0-logloss:0.24035	validation_1-logloss:0.28125
# [468]	validation_0-logloss:0.24028	validation_1-logloss:0.28119
# [469]	validation_0-logloss:0.24020	validation_1-logloss:0.28113
# [470]	validation_0-logloss:0.24000	validation_1-logloss:0.28100
# [471]	validation_0-logloss:0.23993	validation_1-logloss:0.28095
# [472]	validation_0-logloss:0.23983	validation_1-logloss:0.28087
# [473]	validation_0-logloss:0.23976	validation_1-logloss:0.28082
# [474]	validation_0-logloss:0.23969	validation_1-logloss:0.28077
# [475]	validation_0-logloss:0.23956	validation_1-logloss:0.28069
# [476]	validation_0-logloss:0.23943	validation_1-logloss:0.28061
# [477]	validation_0-logloss:0.23935	validation_1-logloss:0.28055
# [478]	validation_0-logloss:0.23926	validation_1-logloss:0.28049
# [479]	validation_0-logloss:0.23920	validation_1-logloss:0.28044
# [480]	validation_0-logloss:0.23913	validation_1-logloss:0.28039
# [481]	validation_0-logloss:0.23894	validation_1-logloss:0.28027
# [482]	validation_0-logloss:0.23883	validation_1-logloss:0.28020
# [483]	validation_0-logloss:0.23878	validation_1-logloss:0.28015
# [484]	validation_0-logloss:0.23867	validation_1-logloss:0.28008
# [485]	validation_0-logloss:0.23856	validation_1-logloss:0.28001
# [486]	validation_0-logloss:0.23848	validation_1-logloss:0.27995
# [487]	validation_0-logloss:0.23843	validation_1-logloss:0.27992
# [488]	validation_0-logloss:0.23832	validation_1-logloss:0.27985
# [489]	validation_0-logloss:0.23826	validation_1-logloss:0.27980
# [490]	validation_0-logloss:0.23798	validation_1-logloss:0.27962
# [491]	validation_0-logloss:0.23792	validation_1-logloss:0.27956
# [492]	validation_0-logloss:0.23785	validation_1-logloss:0.27952
# [493]	validation_0-logloss:0.23773	validation_1-logloss:0.27945
# [494]	validation_0-logloss:0.23768	validation_1-logloss:0.27941
# [495]	validation_0-logloss:0.23762	validation_1-logloss:0.27936
# [496]	validation_0-logloss:0.23755	validation_1-logloss:0.27932
# [497]	validation_0-logloss:0.23737	validation_1-logloss:0.27920
# [498]	validation_0-logloss:0.23732	validation_1-logloss:0.27916
# [499]	validation_0-logloss:0.23725	validation_1-logloss:0.27912
# RMSE: 0.19773747109254483
# R²: -0.4250964297616915
#        Method  Average Return  Std Dev  Sharpe Ratio
#          Base       18.166943 0.129630      1.401444
# Undersampling       15.781196 0.112318      1.405050
#         SMOTE       16.006201 0.113861      1.405772
#     table-gan       15.662728 0.111029      1.410689
# Smotified-gan       16.264411 0.114425      1.421408
#          Base       18.464355 0.130083      1.419425
# Undersampling       15.777935 0.112348      1.404377
#         SMOTE       16.000025 0.113756      1.406524
#     table-gan       15.615455 0.111129      1.405170
# Smotified-gan       16.247030 0.114360      1.420693

# %%
returns_with_sharpe_df.head()
# Out:
#           Method  Average Return   Std Dev  Sharpe Ratio
# 0           Base       18.166943  0.129630      1.401444
# 1  Undersampling       15.781196  0.112318      1.405050
# 2          SMOTE       16.006201  0.113861      1.405772
# 3      table-gan       15.662728  0.111029      1.410689
# 4  Smotified-gan       16.264411  0.114425      1.421408

# %%
"""returns_with_sharpe_df_path = "C:/Users/GCU/Lending_club/Data_Analysis_lending-club/Dataset/"
returns_with_sharpe_df.to_csv(path_or_buf=returns_with_sharpe_df_path+"return_with_sharp.csv", index=False)"""

# %% [markdown]
# ## Benchmark IRR, 무차별 투자

# %%
test_data_path = "C:/Users/GCU/Lending_club/Data_Analysis_lending-club/Dataset/return_feature_test_irr.csv"
test_df= pd.read_csv(test_data_path)

# %%
import pandas as pd
import numpy as np

results = []

def calculate_benchmark_returns(df: pd.DataFrame, top_percent: float = 0.3, risk_free_rate: float = 0.0):

    # Benchmark 1: IRR 기준 상위 top_percent 투자
    df_sorted_irr = df.sort_values(by="irr", ascending=False)
    top_irr_df = df_sorted_irr.head(int(len(df_sorted_irr) * top_percent))
    
    b1_returns = top_irr_df['return']
    b1_mean = b1_returns.mean() * 100
    b1_std = b1_returns.std()
    b1_sharpe = (b1_mean - risk_free_rate) / b1_std if b1_std != 0 else np.nan

    results.append({
        'portfolio': "benchmark1",
        'Average Return': b1_mean,
        'Std Dev': b1_std,
        'Sharpe Ratio': b1_sharpe
    }) 

    # Benchmark 2: 전체 무차별 투자
    b2_returns = df['return']
    b2_mean = b2_returns.mean() * 100
    b2_std = b2_returns.std() 
    b2_sharpe = (b2_mean - risk_free_rate) / b2_std if b2_std != 0 else np.nan

    results.append({
        'portfolio': "benchmark2",
        'Average Return': b2_mean,
        'Std Dev': b2_std,
        'Sharpe Ratio': b2_sharpe
    }) 

    return results

# %%
calculate_benchmark_returns(test_df)

benchmark_df = pd.DataFrame(results)

# %%
benchmark_df.head()
# Out:
#     portfolio  Average Return   Std Dev  Sharpe Ratio
# 0  benchmark1        2.799690  0.383814      7.294384
# 1  benchmark2        4.351517  0.288939     15.060314

# %%
"""import numpy_financial as npf

def calculate_irr(loan_amnt, installment, term_months):
    cash_flows = [-loan_amnt] + [installment] * term_months
    return npf.irr(cash_flows)


test_data['irr'] = test_data.apply(
    lambda row: calculate_irr(row['loan_amnt'], row['installment'], int(row['term_months'])),
    axis=1
)

test_data_irr_path = "C:/Users/GCU/Lending_club/Data_Analysis_lending-club/Dataset/"
test_data.to_csv(path_or_buf=test_data_irr_path+"return_feature_test_irr.csv", index=False)"""
